// %%
%use lets-plot
// Out:
//    <div id="xKWXbO"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.2.0/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("xKWXbO").appendChild(div);
//            };
//            var e = document.getElementById("xKWXbO");
//            e.appendChild(script);
//        })();
//    </script>
//             <div id="kotlin_out_0"></div>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["letsPlotJs"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["letsPlotJs"] = resQueue;
//                 window["call_letsPlotJs"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.2.0/js-package/distr/lets-plot.min.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_0");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_letsPlotJs"] = function(f) {f();};
//                         window.kotlinQueues["letsPlotJs"].forEach(function(f) {f();});
//                         window.kotlinQueues["letsPlotJs"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_letsPlotJs"] = function(f) {};
//                         window.kotlinQueues["letsPlotJs"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource letsPlotJs';
//                         document.getElementById("kotlin_out_0").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>

// %%
@file:DependsOn("org.jetbrains.lets-plot:lets-plot-common:4.5.0")
@file:DependsOn("com.opencsv:opencsv:5.7.1")
@file:DependsOn("org.jetbrains.lets-plot:lets-plot-kotlin-jvm:4.4.1")

import com.opencsv.CSVReader
import java.io.FileReader
import java.time.LocalDateTime
import java.time.format.DateTimeFormatter
import org.jetbrains.letsPlot.*
import org.jetbrains.letsPlot.geom.*
import org.jetbrains.letsPlot.label.*
import org.jetbrains.letsPlot.themes.elementText
import org.jetbrains.letsPlot.themes.theme

val pathToFile: String = "/home/source/srcCode/DSAGitHub004/src/main/java/ru/lainer/DataScience/pressure.csv"
val fileReader = FileReader(pathToFile)
val csvReader = CSVReader(fileReader)
val resultOfReadCSV = csvReader.readAll()
csvReader.close()

val xAxis = mutableListOf<String>() // Список дат
val yAxis = mutableListOf<Int>()    // Список значений давления
for(current in 1 until resultOfReadCSV.size) {
    xAxis.add(resultOfReadCSV[current][0])
    yAxis.add(resultOfReadCSV[current][1].toInt()) //1-Верхнее давление, 2-Нижнее давление
}

// Создаём DataFrame-подобную структуру для lets-plot
val plotData = mapOf(
    "date" to xAxis,
    "pressure" to yAxis
)

// Строим график
val plot = letsPlot(plotData) +
        geomLine(color = "blue", size = 1.0) { x = "date"; y = "pressure" } +
        geomPoint(color = "red", size = 3.0) { x = "date"; y = "pressure" } +
        ggtitle("Динамика верхнего давления") +
        xlab("Дата и время") +
        ylab("Верхнее давление (мм рт. ст.)") +
        theme(axisTextX = elementText(angle = 45, hjust = 1))  // Наклон подписей дат

plot
// Out:
//    <div id="yixVnD"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "ggtitle":{
// "text":"Динамика верхнего давления"
// },
// "mapping":{
// },
// "data":{
// "date":["24.03.25 07:00","24.03.25 15:00","24.03.25 20:00","25.03.25 02:00","25.03.25 07:00","25.03.25 20:00"],
// "pressure":[140.0,130.0,140.0,160.0,140.0,130.0]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "name":"Дата и время"
// },{
// "aesthetic":"y",
// "name":"Верхнее давление (мм рт. ст.)"
// }],
// "layers":[{
// "mapping":{
// "x":"date",
// "y":"pressure"
// },
// "stat":"identity",
// "color":"blue",
// "size":1.0,
// "position":"identity",
// "geom":"line",
// "data":{
// }
// },{
// "mapping":{
// "x":"date",
// "y":"pressure"
// },
// "stat":"identity",
// "color":"red",
// "size":3.0,
// "position":"identity",
// "geom":"point",
// "data":{
// }
// }],
// "theme":{
// "axis_text_x":{
// "angle":45.0,
// "hjust":1.0,
// "blank":false
// }
// }
// };
//            var plotContainer = document.getElementById("yixVnD");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=508ba03a-77d4-47a8-a359-669df93279c3 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pexPUzu .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pexPUzu .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pexPUzu .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pexPUzu .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pexPUzu .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pexPUzu .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pexPUzu .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #